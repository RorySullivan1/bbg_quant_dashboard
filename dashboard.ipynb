# %%
import importlib, subprocess, sys

try:
    import itables  # noqa: F401  (imported for its side effect: presence)
except ImportError:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "itables"],
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL,
        check=True,
    )
    importlib.invalidate_caches()
    import itables  # noqa: F401

# %%
import sys

# Don't write compiled bytecode into the project folder, where it counts
# against the project's size limit (v0.9.41). Only stops *writing*: every
# library still reads its own cached bytecode, so only `src` recompiles.
sys.dont_write_bytecode = True

from src.layout import build_app
build_app()
